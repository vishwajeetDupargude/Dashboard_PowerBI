# %%
import pandas as pd
import json

# %%
with open(r'C:\Users\Vishwajeet\Downloads\data-analytics-project-for-beginners\t20_json_files\t20_json_files/t20_wc_match_results.json') as f:
    data = json.load(f)

df_match = pd.DataFrame(data[0]['matchSummary'])
df_match.head(10)
# Out:
#          team1        team2       winner     margin   ground     matchDate  \
# 0      Namibia    Sri Lanka      Namibia    55 runs  Geelong  Oct 16, 2022
# 1  Netherlands       U.A.E.  Netherlands  3 wickets  Geelong  Oct 16, 2022
# 2     Scotland  West Indies     Scotland    42 runs   Hobart  Oct 17, 2022
# 3      Ireland     Zimbabwe     Zimbabwe    31 runs   Hobart  Oct 17, 2022
# 4      Namibia  Netherlands  Netherlands  5 wickets  Geelong  Oct 18, 2022
# 5    Sri Lanka       U.A.E.    Sri Lanka    79 runs  Geelong  Oct 18, 2022
# 6      Ireland     Scotland      Ireland  6 wickets   Hobart  Oct 19, 2022
# 7  West Indies     Zimbabwe  West Indies    31 runs   Hobart  Oct 19, 2022
# 8  Netherlands    Sri Lanka    Sri Lanka    16 runs  Geelong  Oct 20, 2022
# 9      Namibia       U.A.E.       U.A.E.     7 runs  Geelong  Oct 20, 2022
#
#      scorecard
# 0  T20I # 1823
# 1  T20I # 1825
# 2  T20I # 1826
# 3  T20I # 1828
# 4  T20I # 1830
# 5  T20I # 1832
# 6  T20I # 1833
# ...

# %%
df_match.shape
# Out:
# (45, 7)

# %%
df_match
# Out:
# <class 'list'>
# 219
# {'name': 'Michael van Lingen', 'team': 'Namibia', 'battingStyle': 'Left hand Bat', 'bowlingStyle': 'Left arm Medium', 'playingRole': 'Bowling Allrounder', 'description': ''}
# dict_keys(['name', 'team', 'battingStyle', 'bowlingStyle', 'playingRole', 'description'])

# %%
df_match.rename({ 'scorecard' : 'match_id'}, axis = 1 , inplace = True)
df_match.head()
# Out:
#          team1        team2       winner     margin   ground     matchDate  \
# 0      Namibia    Sri Lanka      Namibia    55 runs  Geelong  Oct 16, 2022
# 1  Netherlands       U.A.E.  Netherlands  3 wickets  Geelong  Oct 16, 2022
# 2     Scotland  West Indies     Scotland    42 runs   Hobart  Oct 17, 2022
# 3      Ireland     Zimbabwe     Zimbabwe    31 runs   Hobart  Oct 17, 2022
# 4      Namibia  Netherlands  Netherlands  5 wickets  Geelong  Oct 18, 2022
#
#       match_id
# 0  T20I # 1823
# 1  T20I # 1825
# 2  T20I # 1826
# 3  T20I # 1828
# 4  T20I # 1830

# %%
match_ids_dict = {}

for index, row in df_match.iterrows():
    key1 = row['team1']+ ' Vs ' + row['team2']
    key2 = row['team2']+ ' Vs ' + row['team1']

    match_ids_dict[key1] = row["match_id"]
    match_ids_dict[key2] = row["match_id"]

match_ids_dict
# Out:
# {'Namibia Vs Sri Lanka': 'T20I # 1823',
#  'Sri Lanka Vs Namibia': 'T20I # 1823',
#  'Netherlands Vs U.A.E.': 'T20I # 1825',
#  'U.A.E. Vs Netherlands': 'T20I # 1825',
#  'Scotland Vs West Indies': 'T20I # 1826',
#  'West Indies Vs Scotland': 'T20I # 1826',
#  'Ireland Vs Zimbabwe': 'T20I # 1828',
#  'Zimbabwe Vs Ireland': 'T20I # 1828',
#  'Namibia Vs Netherlands': 'T20I # 1830',
#  'Netherlands Vs Namibia': 'T20I # 1830',
#  'Sri Lanka Vs U.A.E.': 'T20I # 1832',
#  'U.A.E. Vs Sri Lanka': 'T20I # 1832',
#  'Ireland Vs Scotland': 'T20I # 1833',
#  'Scotland Vs Ireland': 'T20I # 1833',
#  'West Indies Vs Zimbabwe': 'T20I # 1834',
#  'Zimbabwe Vs West Indies': 'T20I # 1834',
#  'Netherlands Vs Sri Lanka': 'T20I # 1835',
#  'Sri Lanka Vs Netherlands': 'T20I # 1835',
#  'Namibia Vs U.A.E.': 'T20I # 1836',
#  'U.A.E. Vs Namibia': 'T20I # 1836',
#  'Ireland Vs West Indies': 'T20I # 1837',
#  'West Indies Vs Ireland': 'T20I # 1837',
#  'Scotland Vs Zimbabwe': 'T20I # 1838',
# ...

# %%
match_ids_dict["Namibia Vs Sri Lanka"]
# Out:
# 'T20I # 1823'

# %%
print(type(match_ids_dict))
# Out:
# <class 'list'>

# %% [markdown]
# **batting Summary**

# %%
with open(r'C:\Users\Vishwajeet\Downloads\data-analytics-project-for-beginners\t20_json_files\t20_json_files/t20_wc_batting_summary.json') as f:
    data = json.load(f)
    all_record =[]
    for rec in data:
        all_record.extend(rec['battingSummary'])

df_batting = pd.DataFrame(all_record)
df_batting.head(11)
# Out:
#                    match teamInnings  battingPos             batsmanName  \
# 0   Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1   Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2   Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3   Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4   Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
# 5   Namibia Vs Sri Lanka     Namibia           6            Jan Frylinck
# 6   Namibia Vs Sri Lanka     Namibia           7             David Wiese
# 7   Namibia Vs Sri Lanka     Namibia           8                 JJ Smit
# 8   Namibia Vs Sri Lanka   Sri Lanka           1         Pathum Nissanka
# 9   Namibia Vs Sri Lanka   Sri Lanka           2         Kusal Mendisâ€
# 10  Namibia Vs Sri Lanka   Sri Lanka           3     Dhananjaya de Silva
#
#                           dismissal runs balls 4s 6s      SR
# ...

# %%
df_batting.head(11)
# Out:
#                    match teamInnings  battingPos             batsmanName  \
# 0   Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1   Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2   Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3   Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4   Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
# 5   Namibia Vs Sri Lanka     Namibia           6            Jan Frylinck
# 6   Namibia Vs Sri Lanka     Namibia           7             David Wiese
# 7   Namibia Vs Sri Lanka     Namibia           8                 JJ Smit
# 8   Namibia Vs Sri Lanka   Sri Lanka           1         Pathum Nissanka
# 9   Namibia Vs Sri Lanka   Sri Lanka           2         Kusal Mendisâ€
# 10  Namibia Vs Sri Lanka   Sri Lanka           3     Dhananjaya de Silva
#
#                           dismissal runs balls 4s 6s      SR
# ...

# %%
df_batting.rename({ 'out/not_out' : 'dismissal'}, axis = 1 , inplace = True)
df_batting.head()
# Out:
#                   match teamInnings  battingPos             batsmanName  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4  Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
#
#                          dismissal runs balls 4s 6s      SR
# 0     c Pramod Madushan b Chameera    3     6  0  0   50.00
# 1      c Shanaka b Pramod Madushan    9     9  1  0  100.00
# 2        c â€ Mendis b Karunaratne   20    12  1  2  166.66
# 3  c DM de Silva b Pramod Madushan   26    24  2  0  108.33
# 4     c Gunathilaka b PWH de Silva   20    24  0  0   83.33

# %%
df_batting["out/not_out"] = df_batting.dismissal.apply(lambda x : "out" if len(x) > 0 else "not_out")
df_batting.head(11)
# Out:
#                    match teamInnings  battingPos             batsmanName  \
# 0   Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1   Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2   Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3   Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4   Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
# 5   Namibia Vs Sri Lanka     Namibia           6            Jan Frylinck
# 6   Namibia Vs Sri Lanka     Namibia           7             David Wiese
# 7   Namibia Vs Sri Lanka     Namibia           8                 JJ Smit
# 8   Namibia Vs Sri Lanka   Sri Lanka           1         Pathum Nissanka
# 9   Namibia Vs Sri Lanka   Sri Lanka           2         Kusal Mendisâ€
# 10  Namibia Vs Sri Lanka   Sri Lanka           3     Dhananjaya de Silva
#
#                           dismissal runs balls 4s 6s      SR out/not_out
# ...

# %%
df_batting.drop(columns =["dismissal"] , inplace = True)
df_batting.head(11)
# Out:
#                    match teamInnings  battingPos             batsmanName runs  \
# 0   Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen    3
# 1   Namibia Vs Sri Lanka     Namibia           2           Divan la Cock    9
# 2   Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton   20
# 3   Namibia Vs Sri Lanka     Namibia           4           Stephan Baard   26
# 4   Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)   20
# 5   Namibia Vs Sri Lanka     Namibia           6            Jan Frylinck   44
# 6   Namibia Vs Sri Lanka     Namibia           7             David Wiese    0
# 7   Namibia Vs Sri Lanka     Namibia           8                 JJ Smit   31
# 8   Namibia Vs Sri Lanka   Sri Lanka           1         Pathum Nissanka    9
# 9   Namibia Vs Sri Lanka   Sri Lanka           2         Kusal Mendisâ€     6
# 10  Namibia Vs Sri Lanka   Sri Lanka           3     Dhananjaya de Silva   12
#
#    balls 4s 6s      SR
# ...

# %%
df_batting['batsmanName'] = df_batting['batsmanName'].apply(lambda x : x.replace('€', ''))
df_batting['batsmanName'] = df_batting['batsmanName'].apply(lambda x : x.replace('\xa0', ''))
df_batting.head(11)
# Out:
#                    match teamInnings  battingPos             batsmanName runs  \
# 0   Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen    3
# 1   Namibia Vs Sri Lanka     Namibia           2           Divan la Cock    9
# 2   Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton   20
# 3   Namibia Vs Sri Lanka     Namibia           4           Stephan Baard   26
# 4   Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)   20
# 5   Namibia Vs Sri Lanka     Namibia           6            Jan Frylinck   44
# 6   Namibia Vs Sri Lanka     Namibia           7             David Wiese    0
# 7   Namibia Vs Sri Lanka     Namibia           8                 JJ Smit   31
# 8   Namibia Vs Sri Lanka   Sri Lanka           1         Pathum Nissanka    9
# 9   Namibia Vs Sri Lanka   Sri Lanka           2           Kusal Mendisâ    6
# 10  Namibia Vs Sri Lanka   Sri Lanka           3     Dhananjaya de Silva   12
#
# ...

# %%
df_batting["match_id"]  = df_batting["match"].map(match_ids_dict)
df_batting.head()
# Out:
#                   match teamInnings  battingPos             batsmanName runs  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen    3
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock    9
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton   20
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard   26
# 4  Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)   20
#
#   balls 4s 6s      SR     match_id
# 0     6  0  0   50.00  T20I # 1823
# 1     9  1  0  100.00  T20I # 1823
# 2    12  1  2  166.66  T20I # 1823
# 3    24  2  0  108.33  T20I # 1823
# 4    24  0  0   83.33  T20I # 1823

# %%
df_batting.to_csv( r'C:\Users\Vishwajeet\Downloads\data-analytics-project-for-beginners\t20_csv_files',
    index=False
)

# %% [markdown]
# **Bowling Summary**

# %%
with open(r'C:\Users\Vishwajeet\Downloads\data-analytics-project-for-beginners\t20_json_files\t20_json_files/t20_wc_bowling_summary.json') as f:
    data = json.load(f)

df_bowling = pd.DataFrame(data[0]['bowlingSummary'])
df_bowling.head(10)
# Out:
#                   match bowlingTeam                  bowlerName overs maiden  \
# 0  Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana     4      0
# 1  Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera     4      0
# 2  Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan     4      0
# 3  Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne     4      0
# 4  Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva     4      0
# 5  Namibia Vs Sri Lanka     Namibia             Gerhard Erasmus     1      0
# 6  Namibia Vs Sri Lanka     Namibia                 David Wiese     4      0
# 7  Namibia Vs Sri Lanka     Namibia             Bernard Scholtz     4      0
# 8  Namibia Vs Sri Lanka     Namibia                Ben Shikongo     3      1
# 9  Namibia Vs Sri Lanka     Namibia                     JJ Smit     3      0
#
#   runs wickets economy  0s 4s 6s wides noBalls
# 0   23       1    5.75   7  0  0     2       0
# ...

# %%
df_bowling.shape
# Out:
# (11, 13)

# %%
df_bowling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   match        11 non-null     object
#  1   bowlingTeam  11 non-null     object
#  2   bowlerName   11 non-null     object
#  3   overs        11 non-null     object
#  4   maiden       11 non-null     object
#  5   runs         11 non-null     object
#  6   wickets      11 non-null     object
#  7   economy      11 non-null     object
#  8   0s           11 non-null     object
#  9   4s           11 non-null     object
#  10  6s           11 non-null     object
#  11  wides        11 non-null     object
#  12  noBalls      11 non-null     object
# dtypes: object(13)
# memory usage: 1.2+ KB

# %%
df_bowling.describe()
# Out:
#                        match bowlingTeam          bowlerName overs maiden  \
# count                     11          11                  11    11     11
# unique                     1           2                  11     3      2
# top     Namibia Vs Sri Lanka     Namibia  Maheesh Theekshana     4      0
# freq                      11           6                   1     8     10
#
#        runs wickets economy  0s  4s  6s wides noBalls
# count    11      11      11  11  11  11    11      11
# unique   10       3      11   6   3   3     3       1
# top      16       1    5.75   7   3   0     0       0
# freq      2       5       1   3   4   6     6      11

# %%
df_bowling[df_bowling["bowlingTeam"]=="Sri Lanka"]
# Out:
#                   match bowlingTeam                  bowlerName overs maiden  \
# 0  Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana     4      0
# 1  Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera     4      0
# 2  Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan     4      0
# 3  Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne     4      0
# 4  Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva     4      0
#
#   runs wickets economy 0s 4s 6s wides noBalls
# 0   23       1    5.75  7  0  0     2       0
# 1   39       1    9.75  6  3  1     2       0
# 2   37       2    9.25  6  3  1     0       0
# 3   36       1    9.00  7  3  1     1       0
# 4   27       1    6.75  8  1  1     0       0

# %%
df_bowling.sort_values("economy")
# Out:
#                    match bowlingTeam                  bowlerName overs maiden  \
# 6   Namibia Vs Sri Lanka     Namibia                 David Wiese     4      0
# 7   Namibia Vs Sri Lanka     Namibia             Bernard Scholtz     4      0
# 9   Namibia Vs Sri Lanka     Namibia                     JJ Smit     3      0
# 0   Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana     4      0
# 10  Namibia Vs Sri Lanka     Namibia                Jan Frylinck     4      0
# 4   Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva     4      0
# 8   Namibia Vs Sri Lanka     Namibia                Ben Shikongo     3      1
# 5   Namibia Vs Sri Lanka     Namibia             Gerhard Erasmus     1      0
# 3   Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne     4      0
# 2   Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan     4      0
# 1   Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera     4      0
#
# ...

# %%
df_bowling.groupby("bowlingTeam")["wickets"].sum()
# Out:
# bowlingTeam
# Namibia      022212
# Sri Lanka     11211
# Name: wickets, dtype: object

# %%
df_bowling["extras"] = df_bowling["wides"] + df_bowling["noBalls"]

# %%
df_bowling.head()
# Out:
#                   match bowlingTeam                  bowlerName overs maiden  \
# 0  Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana     4      0
# 1  Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera     4      0
# 2  Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan     4      0
# 3  Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne     4      0
# 4  Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva     4      0
#
#   runs wickets economy 0s 4s 6s wides noBalls extras
# 0   23       1    5.75  7  0  0     2       0     20
# 1   39       1    9.75  6  3  1     2       0     20
# 2   37       2    9.25  6  3  1     0       0     00
# 3   36       1    9.00  7  3  1     1       0     10
# 4   27       1    6.75  8  1  1     0       0     00

# %%
with open(r'C:\Users\Vishwajeet\Downloads\data-analytics-project-for-beginners\t20_json_files\t20_json_files/t20_wc_player_info.json') as f:
    data = json.load(f)

df_player = pd.DataFrame(data)
df_player.head(10)
# Out:
#                      name       team    battingStyle  \
# 0      Michael van Lingen    Namibia   Left hand Bat
# 1           Divan la Cock    Namibia  Right hand Bat
# 2  Jan Nicol Loftie-Eaton    Namibia   Left hand Bat
# 3           Stephan Baard    Namibia  Right hand Bat
# 4      Gerhard Erasmus(c)    Namibia  Right hand Bat
# 5            Jan Frylinck    Namibia   Left hand Bat
# 6             David Wiese    Namibia  Right hand Bat
# 7                 JJ Smit    Namibia  Right hand Bat
# 8         Pathum Nissanka  Sri Lanka  Right hand Bat
# 9         Kusal Mendisâ€   Sri Lanka  Right hand Bat
#
#                  bowlingStyle          playingRole  \
# 0             Left arm Medium   Bowling Allrounder
# 1                    Legbreak       Opening Batter
# 2  Right arm Medium, Legbreak               Batter
# 3       Right arm Medium fast               Batter
# 4          Right arm Offbreak           Allrounder
# 5        Left arm Fast medium           Allrounder
# ...

# %%
print(type(data))
print(len(data))
print(data[0])
# Out:
# <class 'list'>
# 219
# {'name': 'Michael van Lingen', 'team': 'Namibia', 'battingStyle': 'Left hand Bat', 'bowlingStyle': 'Left arm Medium', 'playingRole': 'Bowling Allrounder', 'description': ''}

# %%
print(data[0].keys())
# Out:
# dict_keys(['name', 'team', 'battingStyle', 'bowlingStyle', 'playingRole', 'description'])
